# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

data = pd.read_csv(r'C:\Users\jonim\Documents\GitHub\analysoinnin-perusteet\archive\ufo-sightings-transformed.csv')

# %%
# to display the first 10 rows of the Pandas DataFrame called chipo
#data.head(10)


#print("Return the number of rows")
#data.shape[0]

#print("Return the number of columns")
#data.shape[1]

#print("Return the number of rows and columns")
#data.shape


#print("Return the names of all columns")
#data.columns


#print("Summary of information like data types and missing values")
#data.info()

#print("Return the index labels that are used")
#data.index

#print("Return data types")
#data.dtypes


#Lajittelu syntax
#data.sort_values(by, axis=0, ascending=True, inplace=False, ignore_index=False)

#data.sort_values("length_of_encounter_seconds")
# Out:
#        Unnamed: 0            Date_time date_documented  Year  Month  Hour  \
# 4081         4081  2008-10-23 04:45:00       1/10/2009  2008     10     4
# 52993       52993  2002-06-30 03:15:00        7/1/2002  2002      6     3
# 23754       23754  1999-12-09 18:15:00      12/16/1999  1999     12    18
# 42376       42376  1987-05-15 23:00:00       1/12/2012  1987      5    23
# 70583       70583  2002-08-30 13:45:00       9/13/2002  2002      8    13
# ...           ...                  ...             ...   ...    ...   ...
# 69211       69211  2002-08-24 01:00:00       8/28/2002  2002      8     1
# 64386       64386  2012-08-10 21:00:00       8/19/2012  2012      8    21
# 74656       74656  1991-09-15 18:00:00       3/31/2008  1991      9    18
# 53381       53381  2010-06-03 23:30:00        7/6/2010  2010      6    23
# 559           559  1983-10-01 17:00:00       4/12/2013  1983     10    17
#
#        Season Country_Code         Country        Region           Locale  \
# ...
